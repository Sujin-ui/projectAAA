# %%
import pandas as pd

data = {'Name':['John','Alice','Bob'],
        'Age':[22,30,22],
        'Gender':['male','female','male'],
        'Salary':[50000,55000,40000]}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Gender  Salary
# 0   John   22    male   50000
# 1  Alice   30  female   55000
# 2    Bob   22    male   40000

# %%
df.loc[0]
# Out:
# Name       John
# Age          25
# Gender     male
# Salary    50000
# Name: 0, dtype: object

# %%
df.iloc[0:1]
# Out:
#    Name  Age Gender  Salary
# 0  John   25   male   50000

# %%
df.iloc[:,0:2]
# Out:
#     Name  Age
# 0   John   25
# 1  Alice   30
# 2    Bob   22

# %%
df.loc[(df['Salary']>=50000) & (df['Age']>= 25) , ['Name']]
# Out:
#     Name
# 0   John
# 1  Alice

# %%
sorted_df = df.sort_values(by='Age')
print(sorted_df)
# Out:
#     Name  Age  Gender  Salary
# 2    Bob   22    male   40000
# 0   John   25    male   50000
# 1  Alice   30  female   55000

# %%
sorted_df = df.sort_values(by=['Age', 'Salary'])
print(sorted_df)
# Out:
#     Name  Age  Gender  Salary
# 2    Bob   22    male   40000
# 0   John   22    male   50000
# 1  Alice   30  female   55000
